# %%
from selenium import webdriver

driver = webdriver.Chrome('C:/Users/고선욱/Documents/ds_study/driver/chromedriver.exe') # 크롬 드라이버 경로 지정
driver.get('https://pinkwink.kr/') # get 명령으로 접근하고 싶은 주소 지정

# %%
# 현재 브라우저 창 크기
driver.get_window_size()
# Out:
# {'width': 945, 'height': 1020}

# %%
driver.get_window_position()
# Out:
# {'x': 10, 'y': 10}

# %%
driver.get_window_rect()
# Out:
# {'height': 1020, 'width': 945, 'x': 10, 'y': 10}

# %%
# 스크롤 가능한 높이(길이)
# 자바스크립트 코드 실행
driver.execute_script('return document.body.scrollHeight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27060/4090773419.py in <module>
#       1 # 스크롤 가능한 높이(길이)
#       2 # 자바스크립트 코드 실행
# ----> 3 driver.execute_script('return document.body.scrollHeight')
#
# NameError: name 'driver' is not defined

# %%
# 화면 스크롤 하단 이동
driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')

# %%
# 화면 스크롤 상단 이동
driver.execute_script('window.scrollTo(0, 0);')

# %%
# 스크린샷
driver.save_screenshot('C:/Users/고선욱/Documents/ds_study/data/last_height.png')
# Out:
# True

# %%
# 특정 태그 지점까지 스크롤 하는 코드

from selenium.webdriver import ActionChains

# some_tag = driver.find_element_by_xpath('''//*[@id="paging"]/ul''')
some_tag = driver.find_element_by_css_selector('#paging > ul')
action = ActionChains(driver)
action.move_to_element(some_tag).perform()

# %%
# 입력 창에 글자 넣기

some_tag = driver.find_element_by_id('gsc-i-id1')
some_tag.send_keys('data science')

# %%
# 브라우저 창 크기 조절
# 현재 보이는 화면에서만 액션을 취할 수 있다
driver.set_window_size(1920, 1080)

# %%
# 화면 최대화
driver.maximize_window()

# %%
# 화면 최소화
driver.minimize_window()

# %%
# 새로 입력하면 뒤에 추가로 붙음
some_tag.send_keys('python')

# %%
# 초기화 후 검색어 입력
some_tag.clear()
some_tag.send_keys('python')

# %% [markdown]
# # Xpath
#
# ```
# // : 최상위 엘리먼트
# * : 자손 태그 검색 => div form # 띄어쓰기=자손태그검색
# / : 자식 태그 검색 => div > form # 꺽쇠=자식태그검색
# td[2] : td 태그 중에서 2번째 태그를 선택 => td:nth_child(2)
# ```

# %% [markdown]
# ## find_element
#
# - find_element_by_css_selector => find, select_one
# - find_elements_by_css_selector => find_all, select

# %%
# xpath

xpath = '''//*[@id="___gcse_0"]/div/form/table/tbody/tr/td[2]/button'''
some_tag = driver.find_element_by_xpath(xpath)
some_tag.click()

# %%
css = "#___gcse_0 > div > form > table > tbody > tr > td:nth-child(2) > button"
some_tag = driver.find_element_by_css_selector(css)
some_tag.click()

# %%
driver.back() # 뒤로 가기

# %%
driver.forward() # 앞으로 가기

# %%
driver.page_source
# Out:
# '<html class="js rgba csscalc opacity supports displaytable display-table cssvhunit cssvwunit mediaqueries textshadow cssanimations backgroundsize boxshadow borderradius boxsizing no-overflowscrolling csstransforms csstransitions csstransforms3d" lang="ko" style=""><head>\n<link rel="stylesheet" type="text/css" href="https://t1.daumcdn.net/tistory_admin/lib/lightbox/css/lightbox.min.css"><link rel="stylesheet" type="text/css" href="https://t1.daumcdn.net/tistory_admin/assets/blog/tistory-244b5bad20db8874c50f4ee71331a0b5d1e3d9f5/blogs/style/content/font.css?_version_=tistory-244b5bad20db8874c50f4ee71331a0b5d1e3d9f5"><link rel="stylesheet" type="text/css" href="https://t1.daumcdn.net/tistory_admin/assets/blog/tistory-244b5bad20db8874c50f4ee71331a0b5d1e3d9f5/blogs/style/content/content.css?_version_=tistory-244b5bad20db8874c50f4ee71331a0b5d1e3d9f5"><!--[if lt IE 9]><script src="https://t1.daumcdn.net/tistory_admin/lib/jquery/jquery-1.12.4.min.js"></script><![endif]--><!--[if gte IE 9]>\
# ...

# %%
from bs4 import BeautifulSoup

req = driver.page_source
soup = BeautifulSoup(req, 'html.parser')

# %%
#e1 > div:nth-child(1) > a

elements = soup.select("#___gcse_0")
elements[0].text
# Out:
# '×검색\xa0'

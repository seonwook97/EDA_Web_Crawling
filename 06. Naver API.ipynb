# %% [markdown]
# # 1. 네이버 API 사용 등록

# %% [markdown]
# - 네이버 개발자 센터
# - https://developers.naver.com/main/
# - Application
#     - 어플리케이션 등록
#     - 어플리케이션 이름 ds_study
#     - 사용 API
#         - 검색
#         - 데이터랩(검색어트렌드)
#         - 데이터랩(쇼핑인사이트)
#     - 환경추가
#         - WEB 설정
#         - http://localhost
#     - Client ID: jOc7UxR_Sp1MMk2mwOq1
#     - Client Secret: s9PY8Vl3Wz
#     - https://developers.naver.com/apps/#/myapps/jOc7UxR_Sp1MMk2mwOq1/overview

# %% [markdown]
# # 2. 네이버 검색 API 사용하기

# %% [markdown]
# - https://developers.naver.com/docs/serviceapi/search/blog/blog.md#%EB%B8%94%EB%A1%9C%EA%B7%B8 # 개발 가이드

# %% [markdown]
# - urllib: http 프로토콜에 따라서 서버의 요청/응답을 처리하기 위한 모듈
# - urllib.request: 클라이언트의 요청을 처리하는 모듈
# - urllib.parse: url 주소에 대한 분석

# %% [markdown]
# ## 검색: 블로그(blog)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "jOc7UxR_Sp1MMk2mwOq1"
client_secret = "s9PY8Vl3Wz"
encText = urllib.parse.quote("삼성전자")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 12 Oct 2021 11:34:56 +0900",
# "total": 2241414,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>삼성전자</b>주가 요즘 날개를 달았네요",
# "link": "https:\/\/blog.naver.com\/kktrigel?Redirect=Log&logNo=222532615954",
# "description": "&lt;봄날에셋 Site주소&gt; www.spring-day.net 전화번호: 070-7884-8553 <b>삼성전자</b>주가 요즘 날개를 달았네요 과거에는 <b>삼성전자</b>주가를 보는 저의 시각은 정말 적금을 넣듯이 들어가는 거라 봤었는데요 요즘 보니까 매일같이... ",
# "bloggername": "저 하늘 깊은 곳에(deep sky)",
# "bloggerlink": "https://blog.naver.com/kktrigel",
# "postdate": "20211010"
#
# },
# {
# "title": "<b>삼성전자</b> 배당금 지급일, 배당락일, 주가 전망 한방에 정리.... ",
# "link": "https:\/\/blog.naver.com\/sirabon?Redirect=Log&logNo=222533412803",
# "description": "분기별 본인이 받을 배당금 계산은 내가 갖고 있는 삼성소유 주식 수 x 361원으로 계산하면 된다. 1000주를 갖고 싶다면 7150만원을 투자해야 한다 <b>삼성전자</b> 배당금 실망하지말자 7150만원 투자하면 분기당... ",
# "bloggername": "재테크",
# "bloggerlink": "https://blog.naver.com/sirabon",
# "postdate": "20211011"
#
# },
# {
# "title": "<b>삼성전자</b>주가는 어디까지 갈까?",
# "link": "https:\/\/blog.naver.com\/thebroome?Redirect=Log&logNo=222532879836",
# "description": "&lt;더트레이더 Site주소&gt; www.trader-fm.com 전화번호: 070-7884-4961 <b>삼성전자</b>주가는 어디까지 갈까? 생각하는 모든... 저에게는 그 길을 열어준 것이 더트레이더었고 그 꿈을 함께 지지해준 것이 <b>삼성전자</b>주가를 알게... ",
# "bloggername": "투투랑",
# "bloggerlink": "https://blog.naver.com/thebroome",
# "postdate": "20211010"
#
# },
# {
# "title": "<b>삼성전자</b>주가 전망과 기대감",
# "link": "https:\/\/blog.naver.com\/lmy0207?Redirect=Log&logNo=222532929043",
# "description": "&lt;베타에셋 Site주소&gt; www.beta-as.net 전화번호: 070-7883-2376 <b>삼성전자</b>주가 전망과 기대감 지난 연말 외국인 매수세에 힘입어 십만 전자를 바라보던 <b>삼성전자</b>주가가 화들짝 놀란 일반인들의 투자금이 몰려든 후 되려... ",
# "bloggername": "YourLife_Trainer",
# "bloggerlink": "https://blog.naver.com/lmy0207",
# "postdate": "20211010"
#
# },
# {
# "title": "삼성 갤럭시 탭 S7 초고속... 45W 충전기, <b>삼성전자</b> 서비스 센터)",
# "link": "https:\/\/blog.naver.com\/wjdrk1225?Redirect=Log&logNo=222533152695",
# "description": "잘못된 정보 이건 <b>삼성전자</b> 서비스 센터에 실망한 점입니다. 뭐 이제 초고속 충전도 사용 가능하고 무상으로 메인보드, 배터리 등을 새 것으로 교체했으니 괜찮습니다. 갤럭시 탭 S7이 삼성 정품 25W, 45W... ",
# "bloggername": "무명 블로그",
# "bloggerlink": "https://blog.naver.com/wjdrk1225",
# "postdate": "20211011"
#
# },
# {
# "title": "<b>삼성전자</b> 앞서가는 파운드리…우회하는 인텔",
# "link": "https:\/\/blog.naver.com\/leealive?Redirect=Log&logNo=222533653605",
# "description": "(21.10.07) <b>삼성전자</b>, 3나노 양산 내년 상반기로 앞당겨 인텔, 나노 경쟁 벗어나 새 판 짜기 시도 [매일일보 이재영 기자]<b>삼성전자</b>가 TSMC보다 선제적으로 내년 상반기 3나노 파운드리 양산 계획을 밝히며... ",
# "bloggername": "신바드의 일곱 항해",
# "bloggerlink": "https://blog.naver.com/leealive",
# "postdate": "20211011"
#
# },
# {
# "title": "&quot;<b>삼성전자</b>에 세계 최초 뺏겼다&quot;…칼 가는 TSMC 어떤 카드 ?",
# "link": "https:\/\/blog.naver.com\/bubsa0701?Redirect=Log&logNo=222533796187",
# "description": "앞서 지난 7일 <b>삼성전자</b>는 온라인으로 개최한 '삼성 파운드리 포럼 2021'에서 내년 상반기 GAA 기술을 활용한 3나노 양산에 도입한다고 했다. 또 2023년에는 3나노 2세대, 2025년에는 GAA 기반 2나노 공정... ",
# "bloggername": "정현법사",
# "bloggerlink": "https://blog.naver.com/bubsa0701",
# "postdate": "20211011"
#
# },
# {
# "title": "호학 재용 : <b>삼성전자</b> 언제살까 ?",
# "link": "https:\/\/blog.naver.com\/knock001?Redirect=Log&logNo=222533871074",
# "description": "https://m.yna.co.kr/view/AKR20211009020100003 우리가 생각할 땐 래미안이나 짓는 건설사인 삼성물산은 아웃 오브 안중으로 관심 밖이고 슈퍼사이클에 10만 전자 간다던 <b>삼성전자</b>가 많이 싸졌다면... ",
# "bloggername": "무르 의 공방",
# "bloggerlink": "https://blog.naver.com/knock001",
# "postdate": "20211011"
#
# },
# {
# "title": "<b>삼성전자</b>우 주가 : 상속세, 지아이텍, 차백신연구소",
# "link": "https:\/\/blog.naver.com\/blanche15?Redirect=Log&logNo=222534372525",
# "description": "<b>삼성전자</b>우 주가 지아이텍 공모주 청약, 차백신연구소 공모주 청약 홍라희여사 상속세 마련위해 <b>삼성전자</b> 주식 1조 4천억 처분 이건희 삼성 회장의 부인인 홍라희 여사는 회장에게 받은 유산에 관한... ",
# "bloggername": "블랑부케'story",
# "bloggerlink": "https://blog.naver.com/blanche15",
# "postdate": "20211012"
#
# },
# {
# "title": "<b>삼성전자</b>와 하이닉스의 주가 폭락 - 겁낼이유?",
# "link": "https:\/\/blog.naver.com\/gunbaram?Redirect=Log&logNo=222534372956",
# "description": "특히 우리나라 주식에서 상당한 지분을 차지하고 있는 <b>삼성전자</b>와 하이닉스를 비롯한 대형주들의 부진은 지수를 더 끌어내리고 있다. <b>삼성전자</b>의 일봉차트 상으로 RSI 는 17까지 내려왔다. 작년 12월 이후 가장... ",
# "bloggername": "주식탐구생활",
# "bloggerlink": "https://blog.naver.com/gunbaram",
# "postdate": "20211012"
#
# }
# ]
# }

# %%
response, response.getcode(), response.code, response.status
# Out:
# (<http.client.HTTPResponse at 0x1c27235b860>, 200, 200, 200)

# %%
# 글자로 읽을 경우, decode utf-8 설정
print(response_body.decode('utf-8'))
# Out:
# {
# "lastBuildDate": "Tue, 12 Oct 2021 11:34:56 +0900",
# "total": 2241414,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>삼성전자</b>주가 요즘 날개를 달았네요",
# "link": "https:\/\/blog.naver.com\/kktrigel?Redirect=Log&logNo=222532615954",
# "description": "&lt;봄날에셋 Site주소&gt; www.spring-day.net 전화번호: 070-7884-8553 <b>삼성전자</b>주가 요즘 날개를 달았네요 과거에는 <b>삼성전자</b>주가를 보는 저의 시각은 정말 적금을 넣듯이 들어가는 거라 봤었는데요 요즘 보니까 매일같이... ",
# "bloggername": "저 하늘 깊은 곳에(deep sky)",
# "bloggerlink": "https://blog.naver.com/kktrigel",
# "postdate": "20211010"
#
# },
# {
# "title": "<b>삼성전자</b> 배당금 지급일, 배당락일, 주가 전망 한방에 정리.... ",
# "link": "https:\/\/blog.naver.com\/sirabon?Redirect=Log&logNo=222533412803",
# "description": "분기별 본인이 받을 배당금 계산은 내가 갖고 있는 삼성소유 주식 수 x 361원으로 계산하면 된다. 1000주를 갖고 싶다면 7150만원을 투자해야 한다 <b>삼성전자</b> 배당금 실망하지말자 7150만원 투자하면 분기당... ",
# "bloggername": "재테크",
# "bloggerlink": "https://blog.naver.com/sirabon",
# "postdate": "20211011"
#
# },
# {
# "title": "<b>삼성전자</b>주가는 어디까지 갈까?",
# "link": "https:\/\/blog.naver.com\/thebroome?Redirect=Log&logNo=222532879836",
# "description": "&lt;더트레이더 Site주소&gt; www.trader-fm.com 전화번호: 070-7884-4961 <b>삼성전자</b>주가는 어디까지 갈까? 생각하는 모든... 저에게는 그 길을 열어준 것이 더트레이더었고 그 꿈을 함께 지지해준 것이 <b>삼성전자</b>주가를 알게... ",
# "bloggername": "투투랑",
# "bloggerlink": "https://blog.naver.com/thebroome",
# "postdate": "20211010"
#
# },
# {
# "title": "<b>삼성전자</b>주가 전망과 기대감",
# "link": "https:\/\/blog.naver.com\/lmy0207?Redirect=Log&logNo=222532929043",
# "description": "&lt;베타에셋 Site주소&gt; www.beta-as.net 전화번호: 070-7883-2376 <b>삼성전자</b>주가 전망과 기대감 지난 연말 외국인 매수세에 힘입어 십만 전자를 바라보던 <b>삼성전자</b>주가가 화들짝 놀란 일반인들의 투자금이 몰려든 후 되려... ",
# "bloggername": "YourLife_Trainer",
# "bloggerlink": "https://blog.naver.com/lmy0207",
# "postdate": "20211010"
#
# },
# {
# "title": "삼성 갤럭시 탭 S7 초고속... 45W 충전기, <b>삼성전자</b> 서비스 센터)",
# "link": "https:\/\/blog.naver.com\/wjdrk1225?Redirect=Log&logNo=222533152695",
# "description": "잘못된 정보 이건 <b>삼성전자</b> 서비스 센터에 실망한 점입니다. 뭐 이제 초고속 충전도 사용 가능하고 무상으로 메인보드, 배터리 등을 새 것으로 교체했으니 괜찮습니다. 갤럭시 탭 S7이 삼성 정품 25W, 45W... ",
# "bloggername": "무명 블로그",
# "bloggerlink": "https://blog.naver.com/wjdrk1225",
# "postdate": "20211011"
#
# },
# {
# "title": "<b>삼성전자</b> 앞서가는 파운드리…우회하는 인텔",
# "link": "https:\/\/blog.naver.com\/leealive?Redirect=Log&logNo=222533653605",
# "description": "(21.10.07) <b>삼성전자</b>, 3나노 양산 내년 상반기로 앞당겨 인텔, 나노 경쟁 벗어나 새 판 짜기 시도 [매일일보 이재영 기자]<b>삼성전자</b>가 TSMC보다 선제적으로 내년 상반기 3나노 파운드리 양산 계획을 밝히며... ",
# "bloggername": "신바드의 일곱 항해",
# "bloggerlink": "https://blog.naver.com/leealive",
# "postdate": "20211011"
#
# },
# {
# "title": "&quot;<b>삼성전자</b>에 세계 최초 뺏겼다&quot;…칼 가는 TSMC 어떤 카드 ?",
# "link": "https:\/\/blog.naver.com\/bubsa0701?Redirect=Log&logNo=222533796187",
# "description": "앞서 지난 7일 <b>삼성전자</b>는 온라인으로 개최한 '삼성 파운드리 포럼 2021'에서 내년 상반기 GAA 기술을 활용한 3나노 양산에 도입한다고 했다. 또 2023년에는 3나노 2세대, 2025년에는 GAA 기반 2나노 공정... ",
# "bloggername": "정현법사",
# "bloggerlink": "https://blog.naver.com/bubsa0701",
# "postdate": "20211011"
#
# },
# {
# "title": "호학 재용 : <b>삼성전자</b> 언제살까 ?",
# "link": "https:\/\/blog.naver.com\/knock001?Redirect=Log&logNo=222533871074",
# "description": "https://m.yna.co.kr/view/AKR20211009020100003 우리가 생각할 땐 래미안이나 짓는 건설사인 삼성물산은 아웃 오브 안중으로 관심 밖이고 슈퍼사이클에 10만 전자 간다던 <b>삼성전자</b>가 많이 싸졌다면... ",
# "bloggername": "무르 의 공방",
# "bloggerlink": "https://blog.naver.com/knock001",
# "postdate": "20211011"
#
# },
# {
# "title": "<b>삼성전자</b>우 주가 : 상속세, 지아이텍, 차백신연구소",
# "link": "https:\/\/blog.naver.com\/blanche15?Redirect=Log&logNo=222534372525",
# "description": "<b>삼성전자</b>우 주가 지아이텍 공모주 청약, 차백신연구소 공모주 청약 홍라희여사 상속세 마련위해 <b>삼성전자</b> 주식 1조 4천억 처분 이건희 삼성 회장의 부인인 홍라희 여사는 회장에게 받은 유산에 관한... ",
# "bloggername": "블랑부케'story",
# "bloggerlink": "https://blog.naver.com/blanche15",
# "postdate": "20211012"
#
# },
# {
# "title": "<b>삼성전자</b>와 하이닉스의 주가 폭락 - 겁낼이유?",
# "link": "https:\/\/blog.naver.com\/gunbaram?Redirect=Log&logNo=222534372956",
# "description": "특히 우리나라 주식에서 상당한 지분을 차지하고 있는 <b>삼성전자</b>와 하이닉스를 비롯한 대형주들의 부진은 지수를 더 끌어내리고 있다. <b>삼성전자</b>의 일봉차트 상으로 RSI 는 17까지 내려왔다. 작년 12월 이후 가장... ",
# "bloggername": "주식탐구생활",
# "bloggerlink": "https://blog.naver.com/gunbaram",
# "postdate": "20211012"
#
# }
# ]
# }

# %% [markdown]
# ## 검색: 책(book)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "jOc7UxR_Sp1MMk2mwOq1"
client_secret = "s9PY8Vl3Wz"
encText = urllib.parse.quote("삼성전자")
url = "https://openapi.naver.com/v1/search/book?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 12 Oct 2021 11:39:10 +0900",
# "total": 3216,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "GSAT 직무적성검사 <b>삼성전자</b> 5급 고졸채용 (2021)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18875215",
# "image": "https://bookthumb-phinf.pstatic.net/cover/188/752/18875215.jpg?type=m1&udate=20210413",
# "author": "JH적성검사연구소",
# "price": "22000",
# "discount": "19800",
# "publisher": "미디어정훈",
# "pubdate": "20210420",
# "isbn": "1166430308 9791166430305",
# "description": "2021 <b>삼성전자</b> 고졸채용 대비 GSAT 5급 기본서<b>삼성전자</b>에서는 인재 채용을 위해 삼성직무적성검사, GSAT를 활용한다. GSAT는 지원 학력에 따라 3급, 4급, 5급으로 나뉘며 고등학교 졸업, 또는 고등학교 졸업과 동일한 수준의 학력인 지원자들을 대상으로는 5급이 시행되고 있다. GSAT 5급은 3급과 시행하는... "
#
# },
# {
# "title": "<b>삼성전자</b> 주식을 알면 주식 투자의 길이 보인다",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=17805531",
# "image": "https://bookthumb-phinf.pstatic.net/cover/178/055/17805531.jpg?type=m1&udate=20210227",
# "author": "김민후",
# "price": "16000",
# "discount": "14400",
# "publisher": "북오션",
# "pubdate": "20210210",
# "isbn": "8967995806 9788967995805",
# "description": "# 국내 최초로 <b>삼성전자</b> 주식을 입체분석한 책\n# 매매 기법, 투자 철학, 종목 선정 방법 등 주식 투자의... 넘던 <b>삼성전자</b> 주식은 시장가 약 5만원짜리 주식으로 액명분할 하면서, 이른바 ‘국민주식’이 되었다. 우리나라 코스피 시가총액의 약 25%를 차지하는 <b>삼성전자</b>는 매년 꾸준히 놀라운 이익을 내고 있으며... "
#
# },
# {
# "title": "2020 <b>삼성전자</b> GSAT 직무적성검사 3회분 봉투모의고사",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16347717",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/477/16347717.jpg?type=m1&udate=20200507",
# "author": "취업적성연구소",
# "price": "15000",
# "discount": "",
# "publisher": "서원각",
# "pubdate": "20200508",
# "isbn": "1125730439 9791125730439",
# "description": "▶ 특  징\n다양한 유형과 난이도의 문제\n3회분 모의고사"
#
# },
# {
# "title": "GSAT 5급 <b>삼성전자</b> 직무적성검사 고졸채용 (2018 최신기출문제,실전모의고사,2019)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14300358",
# "image": "https://bookthumb-phinf.pstatic.net/cover/143/003/14300358.jpg?type=m1&udate=20190530",
# "author": "JH적성검사연구소",
# "price": "22000",
# "discount": "",
# "publisher": "정훈사",
# "pubdate": "20190125",
# "isbn": "1185940677 9791185940670",
# "description": "GSAT 최신기출문제 복원?수록\n2018년 삼성의 GSAT 최신기출문제를 복원하여 수록하여 GSAT 기초능력검사의 출제유형을 미리 파악할 수 있도록 하였다.\n2.... 삼성의 면접 전형과 <b>삼성전자</b> 기출질문합격의 최종 관문인 면접에서 삼성 면접의 유형과 예시문항을 제시하였고, <b>삼성전자</b> 면접 기출문제를 수록해... "
#
# },
# {
# "title": "반도체 핵심 <b>삼성전자</b> 취업을 위해 꼭 알아야 할 용어와 이슈",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20771088",
# "image": "https://bookthumb-phinf.pstatic.net/cover/207/710/20771088.jpg?type=m1&udate=20210717",
# "author": "비피기술거래",
# "price": "19500",
# "discount": "17550",
# "publisher": "비피기술거래",
# "pubdate": "20210716",
# "isbn": "1161825061 9791161825069",
# "description": "일자리는 부족하고 실업률은 높은 시대이다\n코로나19가 닥치기 전에도 한국의 청년 실업률은 \n다른 국가에 비해 높은 수준이었다\n또한 청년층 체감 실업률도 여전히 높다\n\n그래서 우린 자신만의 경쟁력을 키워 \n취업 시장에 도전해야 한다\n\n<b>삼성전자</b>는 우리나라 주식시장 시가총액 1위를 차지하며 \n시가총액이... "
#
# },
# {
# "title": "2021 GSAT <b>삼성전자</b> 직무적성검사 온라인 시험 대비 5회분 봉투모의고사 (수리영역＋추리영역) (GSAT <b>삼성전자</b> 온라인 시험대비)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=18904303",
# "image": "https://bookthumb-phinf.pstatic.net/cover/189/043/18904303.jpg?type=m1&udate=20210415",
# "author": "취업적성연구소",
# "price": "15000",
# "discount": "13500",
# "publisher": "서원각",
# "pubdate": "20210421",
# "isbn": "1125735171 9791125735175",
# "description": "｜포인트 1. GSAT <b>삼성전자</b> 직무적성검사 온라인 시험 대비\n｜포인트 2. 출제경향에 맞춘 직무적성검사 50문항으로 구성된 5회분 모의고사\n｜포인트 3. 수리영역, 추리영역 수록\n｜포인트 4. 학습의 효율을 높이는 상세한 해설\n｜포인트 5. 실전 완벽대비를 위한 답안지 수록"
#
# },
# {
# "title": "GSAT 5급 <b>삼성전자</b> 직무적성검사 고졸 채용 (2018)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=12486681",
# "image": "https://bookthumb-phinf.pstatic.net/cover/124/866/12486681.jpg?type=m1&udate=20180912",
# "author": "JH적성검사연구소",
# "price": "20000",
# "discount": "",
# "publisher": "정훈사",
# "pubdate": "20180118",
# "isbn": "8961296116 9788961296113",
# "description": "<b>삼성전자</b> 5급 고졸 채용시험을 대비할 수 있는 수험서로서 지금까지의 출제경향을 꼼꼼히 분석하여 내용을 구성하였다. 특히 최근기출문제를 완벽... 또한, U-K검사와 인성검사는 물론 <b>삼성전자</b>의 면접 기출질문을 수록하여 GSAT 5급 시험 전반을 준비할 수 있도록 배려하였다. 마지막으로 실전모의고사를... "
#
# },
# {
# "title": "2020 <b>삼성전자</b> GSAT(온라인 시험 대비) 직무적성검사(수리영역/추리영역) 봉투모의고사 (온라인 시험 영역 반영)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16359724",
# "image": "https://bookthumb-phinf.pstatic.net/cover/163/597/16359724.jpg?type=m1&udate=20200516",
# "author": "취업적성연구소",
# "price": "10000",
# "discount": "",
# "publisher": "서원각",
# "pubdate": "20200527",
# "isbn": "1125730676 9791125730675",
# "description": "2020년 GSAT 온라인 시험 대비서이다. 수리영역/ 추리영역 2과목으로 구성되었으며, 3회분 모의고사를 수록하였다."
#
# },
# {
# "title": "기쎈 <b>삼성전자</b> GSAT 삼성직무적성검사 봉투모의고사",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14037061",
# "image": "https://bookthumb-phinf.pstatic.net/cover/140/370/14037061.jpg?type=m1&udate=20190530",
# "author": "취업적성연구소",
# "price": "15000",
# "discount": "",
# "publisher": "서원각",
# "pubdate": "20181001",
# "isbn": "1125723939 9791125723936",
# "description": "<b>삼성전자</b> GSAT 삼성직무적성검사 대비 봉투모의고사\n최신 출제경향에 맞춰 모의고사 3회분 수록\n실제 시험과 유사한 문제로 모의고사 구성\n꼼꼼하고 상세한 정답 및 해설"
#
# },
# {
# "title": "<b>삼성전자</b> 핫 키워드와 이슈 모르면 주식 대박 힘들다",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20677291",
# "image": "https://bookthumb-phinf.pstatic.net/cover/206/772/20677291.jpg?type=m1&udate=20210626",
# "author": "서울공대OB주식연구회",
# "price": "19500",
# "discount": "17550",
# "publisher": "비피기술거래",
# "pubdate": "20210625",
# "isbn": "1161825029 9791161825021",
# "description": "<b>삼성전자</b>는 우리나라 주식시장 시가총액 1위를 차지하며\n시가총액이 약 480조원에 이르는 초거대 기업이다\n\n<b>삼성전자</b>는 1969년 <b>삼성전자</b>공업주식회사로 출발하여\n1978년 삼성반도체로 상호를 변경한 후 \n미국의 실리콘밸리를 시찰한 후부터 \n적극적으로 반도체 사업에 뛰어들게 되었으며 \n1991년... "
#
# }
# ]
# }

# %% [markdown]
# ## 검색: 영화(movie)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "jOc7UxR_Sp1MMk2mwOq1"
client_secret = "s9PY8Vl3Wz"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/movie?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 12 Oct 2021 11:40:59 +0900",
# "total": 1,
# "start": 1,
# "display": 1,
# "items": [
# {
# "title": "<b>파이썬</b> 앤 가드",
# "link": "https://movie.naver.com/movie/bi/mi/basic.nhn?code=152070",
# "image": "https://ssl.pstatic.net/imgmovie/mdi/mit110/1520/152070_P01_145336.jpg",
# "subtitle": "PYTHON AND GUARD",
# "pubDate": "2015",
# "director": "안톤 디아코프|",
# "actor": "",
# "userRating": "0.00"
#
# }
# ]
# }

# %% [markdown]
# ## 검색: 카페(cafearticle)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "jOc7UxR_Sp1MMk2mwOq1"
client_secret = "s9PY8Vl3Wz"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 12 Oct 2021 11:41:26 +0900",
# "total": 121786,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b> 강의 프로그래밍 수업 무료로 듣자!",
# "link": "http://cafe.naver.com/anjun/885594",
# "description": "※이 글은 산준모카페 관리자 승인 하에 작성된 글입니다 <b>파이썬</b> 강의 프로그래밍 수업 무료로 듣자! <b>파이썬</b> 강의 프로그래밍 수업 무료로 듣자! 안녕하세요 IT전문 학습멘토 동자쌤입니다 프로그래밍을 배우기로... ",
# "cafename": "산준모★산업안전기사｜위험물산업기사...",
# "cafeurl": "https://cafe.naver.com/anjun"
#
# },
# {
# "title": "<b>파이썬</b> 교재 추천해주세요",
# "link": "http://cafe.naver.com/forasteacher/158057",
# "description": "초6아이에요 다른 코딩 자격증 준비중이고 곧 마무리될 단계라서 다음 과정으로 <b>파이썬</b>해주고 싶은데 초등 애들이 사용할 만한 교재 추천 부탁드려요 그리고 혹시 아이들 중에 diat <b>파이썬</b> 자격증 시험 진행해보신분들... ",
# "cafename": "방세아.방과후.돌봄.공부방.유치원",
# "cafeurl": "https://cafe.naver.com/forasteacher"
#
# },
# {
# "title": "<b>파이썬</b>기초학원 쉽게 교육받는 방법 공유합니다.",
# "link": "http://cafe.naver.com/nomacomnovels2/1985",
# "description": "오늘은 <b>파이썬</b>기초학원에서 <b>파이썬</b>과 관련된 여러가지 이야기를 나눠보도록 할건데요! 바로 시작해보도록 할게요~ Let's go! <b>파이썬</b>에 대한 간략한 소개! <b>파이썬</b>은 네덜란드 Guido van Rossum이 만든 언어로 알려져... ",
# "cafename": "IT로 성공하는 사람들 - 아성사 ( IT공...",
# "cafeurl": "https://cafe.naver.com/nomacomnovels2"
#
# },
# {
# "title": "<b>파이썬</b> 도서",
# "link": "http://cafe.naver.com/mathall/2268240",
# "description": "안녕하세요~ 아이가 <b>파이썬</b>책을 사달라네요 혼자라도 해보고 싶다는데 어떤책을 사줘야할지를 모르겠네요 <b>파이썬</b> 책 활용하기 좋은것으로 아시는분 계시면 도움부탁드립니다~~♡♡",
# "cafename": "[상위1%카페] 대한민국 상위1% 교육정...",
# "cafeurl": "https://cafe.naver.com/mathall"
#
# },
# {
# "title": "<b>파이썬</b> 배우는 법",
# "link": "http://cafe.naver.com/inmacbook/2470930",
# "description": "맥북으로 <b>파이썬</b>을 배우려고 합니다. 혹시 유튜브에 맥기반으로 파이선 강의하는 사이트가 있을가요? 맥기반이 아니더라도 <b>파이썬</b> 초보가 쉽게 배울수 있는 유투버 추천 부탁드립니다.",
# "cafename": "맥 쓰는 사람들 [구 맥북을 쓰는 사람...",
# "cafeurl": "https://cafe.naver.com/inmacbook"
#
# },
# {
# "title": "반도체쪽 <b>파이썬</b> 자격증",
# "link": "http://cafe.naver.com/dokchi/11273200",
# "description": "이쪽에서도 <b>파이썬</b>이 많이 쓰인다고 하여 <b>파이썬</b>관련 자격증을 하나 취득해볼까 하는데 <b>파이썬</b> 마스터, Cos Pro Python 이 둘 중에서 고민중입니다. 혹시 어느쪽이 좀 더 도움이 될까요..? 답변... ",
# "cafename": "독취사-취업,대학생,대기업,공기업,GS...",
# "cafeurl": "https://cafe.naver.com/dokchi"
#
# },
# {
# "title": "<b>파이썬</b> 독학사이트(coding-insight.com) 업데이트 소개드려요.",
# "link": "http://cafe.naver.com/pangyomommy/519978",
# "description": "낙원중학교 1학년 친구들의 '<b>파이썬</b> 팩토리' 동아리가 지난주 한국과학창의재단의 2차 온라인 자문을... 등을 <b>파이썬</b>을 통해 구현해볼 수 있는 동영상을 올리고 각 강좌 소개동영상을 올리기 시작했어요. https://youtu.... ",
# "cafename": "[판교맘] 판교 엄마들의 모임",
# "cafeurl": "https://cafe.naver.com/pangyomommy"
#
# },
# {
# "title": "ADP 실기와 빅분기 실기// <b>파이썬</b> or R",
# "link": "http://cafe.naver.com/sqlpd/25148",
# "description": "예전 학부 때 복수전공하면서 계량경제학 과목을 R로 한 학기동안 만져본적 있는데(교수님이 R로만 하심), ADP나 빅분기 실기는 훨씬 더 어려울거 같아 <b>파이썬</b>으로 준비할지 R로 준비할지 고민됩니다. 사실 한 학기동안... ",
# "cafename": "데이터 전문가 포럼 (빅데이터분석기사...",
# "cafeurl": "https://cafe.naver.com/sqlpd"
#
# },
# {
# "title": "<b>파이썬</b> 책을 사야할까요??",
# "link": "http://cafe.naver.com/kongdae/140672",
# "description": "2학기부터 정보시간에 <b>파이썬</b> 배우기 시작했는데 교과서에는 내용이 충분하지 않은것 같아요ㅠㅠ 컴공과를... 하나 사두고 참고하면서 이것저것 해보고 싶긴 한데 <b>파이썬</b>에 쏟을 수 있는 시간이 많이 나지는 않을것... ",
# "cafename": "[이공계의 별★서울대,KAIST,POSTECH,...",
# "cafeurl": "https://cafe.naver.com/kongdae"
#
# },
# {
# "title": "<b>파이썬</b>으로 plc 데이터 받아서 db에 저장하는게 가능한가요?",
# "link": "http://cafe.naver.com/cplc/297952",
# "description": "일반적으로 c#을 많이쓰는걸로 알고 있는데 <b>파이썬</b>으로 가능한지해서... 잘 안쓰면 왜안쓰는지...질문을 남겨봅니다.!",
# "cafename": "컴퓨터일반과PLC",
# "cafeurl": "https://cafe.naver.com/cplc"
#
# }
# ]
# }

# %% [markdown]
# ## 검색: 쇼핑(shop)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "jOc7UxR_Sp1MMk2mwOq1"
client_secret = "s9PY8Vl3Wz"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 12 Oct 2021 11:42:02 +0900",
# "total": 344155,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "골든구스 슈퍼스타 <b>파이톤</b> 여자 스니커즈 GWF00102 F000761 10402",
# "link": "https://search.shopping.naver.com/gate.nhn?id=27539981407",
# "image": "https://shopping-phinf.pstatic.net/main_2753998/27539981407.20210612003415.jpg",
# "lprice": "366840",
# "hprice": "",
# "mallName": "네이버",
# "productId": "27539981407",
# "productType": "1",
# "brand": "골든구스",
# "maker": "골든구스",
# "category1": "패션잡화",
# "category2": "여성신발",
# "category3": "단화",
# "category4": "스니커즈"
#
# },
# {
# "title": "칼린 모드 H79163010",
# "link": "https://search.shopping.naver.com/gate.nhn?id=18402726379",
# "image": "https://shopping-phinf.pstatic.net/main_1840272/18402726379.20210604103232.jpg",
# "lprice": "68710",
# "hprice": "",
# "mallName": "네이버",
# "productId": "18402726379",
# "productType": "1",
# "brand": "칼린",
# "maker": "",
# "category1": "패션잡화",
# "category2": "여성가방",
# "category3": "크로스백",
# "category4": ""
#
# },
# {
# "title": "샤를리즈 <b>파이톤</b>백 POWT-1027",
# "link": "https://search.shopping.naver.com/gate.nhn?id=23134625806",
# "image": "https://shopping-phinf.pstatic.net/main_2313462/23134625806.20200613171707.jpg",
# "lprice": "88290",
# "hprice": "",
# "mallName": "네이버",
# "productId": "23134625806",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "패션잡화",
# "category2": "여성가방",
# "category3": "토트백",
# "category4": ""
#
# },
# {
# "title": "잘모이 셀리나 리얼 <b>파이톤</b> 스마트백 LTZ-5217",
# "link": "https://search.shopping.naver.com/gate.nhn?id=29034170281",
# "image": "https://shopping-phinf.pstatic.net/main_2903417/29034170281.20210929210506.jpg",
# "lprice": "88200",
# "hprice": "",
# "mallName": "네이버",
# "productId": "29034170281",
# "productType": "1",
# "brand": "잘모이",
# "maker": "",
# "category1": "패션잡화",
# "category2": "여성가방",
# "category3": "토트백",
# "category4": ""
#
# },
# {
# "title": "잘모이 피플오브더월드 또리에 메간 <b>파이톤</b>백 POWT-1028",
# "link": "https://search.shopping.naver.com/gate.nhn?id=23134182510",
# "image": "https://shopping-phinf.pstatic.net/main_2313418/23134182510.20200613154000.jpg",
# "lprice": "85020",
# "hprice": "",
# "mallName": "네이버",
# "productId": "23134182510",
# "productType": "1",
# "brand": "잘모이",
# "maker": "",
# "category1": "패션잡화",
# "category2": "여성가방",
# "category3": "토트백",
# "category4": ""
#
# },
# {
# "title": "사만사타바사 럭키 Lucky 미니백 15371MI68",
# "link": "https://search.shopping.naver.com/gate.nhn?id=24143307710",
# "image": "https://shopping-phinf.pstatic.net/main_2414330/24143307710.20211004002608.jpg",
# "lprice": "73370",
# "hprice": "",
# "mallName": "네이버",
# "productId": "24143307710",
# "productType": "1",
# "brand": "사만사타바사",
# "maker": "",
# "category1": "패션잡화",
# "category2": "여성가방",
# "category3": "크로스백",
# "category4": ""
#
# },
# {
# "title": "잘모이 최신상 리얼 <b>파이톤</b> 셀리나 빅 토트",
# "link": "https://search.shopping.naver.com/gate.nhn?id=26501844713",
# "image": "https://shopping-phinf.pstatic.net/main_2650184/26501844713.20210324211416.jpg",
# "lprice": "276200",
# "hprice": "",
# "mallName": "네이버",
# "productId": "26501844713",
# "productType": "1",
# "brand": "잘모이",
# "maker": "",
# "category1": "패션잡화",
# "category2": "여성가방",
# "category3": "토트백",
# "category4": ""
#
# },
# {
# "title": "르까프 여성 <b>파이썬</b>18 PP 1118ST151",
# "link": "https://search.shopping.naver.com/gate.nhn?id=27397012345",
# "image": "https://shopping-phinf.pstatic.net/main_2739701/27397012345.20210602025256.jpg",
# "lprice": "20230",
# "hprice": "",
# "mallName": "네이버",
# "productId": "27397012345",
# "productType": "1",
# "brand": "르까프",
# "maker": "",
# "category1": "패션잡화",
# "category2": "여성신발",
# "category3": "운동화",
# "category4": "러닝화"
#
# },
# {
# "title": "샌디 <b>파이톤</b> 핸드백 LTZ-5194",
# "link": "https://search.shopping.naver.com/gate.nhn?id=23455192579",
# "image": "https://shopping-phinf.pstatic.net/main_2345519/23455192579.20200714190521.jpg",
# "lprice": "98280",
# "hprice": "",
# "mallName": "네이버",
# "productId": "23455192579",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "패션잡화",
# "category2": "여성가방",
# "category3": "토트백",
# "category4": ""
#
# },
# {
# "title": "젬므 <b>파이톤</b>백 스카프 LTZ-5181",
# "link": "https://search.shopping.naver.com/gate.nhn?id=22164931999",
# "image": "https://shopping-phinf.pstatic.net/main_2216493/22164931999.20200310151009.jpg",
# "lprice": "98990",
# "hprice": "",
# "mallName": "네이버",
# "productId": "22164931999",
# "productType": "1",
# "brand": "",
# "maker": "",
# "category1": "패션잡화",
# "category2": "여성가방",
# "category3": "토트백",
# "category4": ""
#
# }
# ]
# }

# %% [markdown]
# ## 검색: 백과사전(encyc)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "jOc7UxR_Sp1MMk2mwOq1"
client_secret = "s9PY8Vl3Wz"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/encyc?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 12 Oct 2021 11:42:38 +0900",
# "total": 444,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>파이썬</b>",
# "link": "https://terms.naver.com/entry.naver?docId=3580815&cid=59088&categoryId=59096",
# "description": "‘<b>파이썬</b>’이다. 간결한 문법으로 입문자가 이해하기 쉽고, 다양한 분야에 활용할 수 있기 때문이다. 이 외에도 <b>파이썬</b>은 머신러닝, 그래픽, 웹 개발 등 여러 업계에서 선호하는 언어로 꾸준히... ",
# "thumbnail": "http://openapi-dbscthumb.phinf.naver.net/4749_000_1/20170118193349632_0CHSSS5Y6.png/01_16.png?type=m160_160"
#
# },
# {
# "title": "<b>파이썬</b>",
# "link": "https://terms.naver.com/entry.naver?docId=3607513&cid=58598&categoryId=59316",
# "description": " 컴퓨터 언어의 일종으로 간결하고 생산성 높은 프로그래밍 언어.  <b>파이썬</b>(python)은 프로그램을 설계하는 프로그래밍 언어 중 하나입니다. 컴퓨터는 0과 1을(이진수) 인식하여 작동하기 때문에 과거에는... ",
# "thumbnail": "http://openapi-dbscthumb.phinf.naver.net/4751_000_3/20170710213206672_OPHLG2VOW.jpg/992_170575_10034.jpg?type=m160_160"
#
# },
# {
# "title": "<b>파이썬</b>",
# "link": "https://terms.naver.com/entry.naver?docId=3533295&cid=40942&categoryId=32838",
# "description": " 오픈소스 고급 프로그래밍 언어 중 하나이다.  C언어를 기반으로 한 오픈소스 고급 프로그래밍 언어로, 1991년 귀도 반 로섬(Guido van Rossum)에 의해 설계 및 개발되었다. <b>파이썬</b>이라는 이름은 <b>파이썬</b>을... ",
# "thumbnail": ""
#
# },
# {
# "title": "<b>파이썬</b>",
# "link": "https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC",
# "description": "<b>파이썬</b> ( 영어: Python )은 1991년 프로그래머인 귀도 반 로섬이 발표한 고급 프로그래밍 언어로, 플랫폼에 독립적이며 인터프리터식, 객체지향적, 동적 타이핑(dynamically typed) 대화형 언어이다.... ",
# "thumbnail": ""
#
# },
# {
# "title": "C<b>파이썬</b>",
# "link": "https://ko.wikipedia.org/wiki/C%ED%8C%8C%EC%9D%B4%EC%8D%AC",
# "description": "C<b>파이썬</b> (CPython)은 <b>파이썬</b> 프로그래밍 언어의 참조 구현체이다. C와 <b>파이썬</b>으로 작성된 C<b>파이썬</b>은 이 언어에 가장 널리 사용되는 기본 구현체이다. C<b>파이썬</b>은 인터프리트 과정 이전에 <b>파이썬</b> 코드를... ",
# "thumbnail": ""
#
# },
# {
# "title": "바이오<b>파이썬</b>",
# "link": "https://ko.wikipedia.org/wiki/%EB%B0%94%EC%9D%B4%EC%98%A4%ED%8C%8C%EC%9D%B4%EC%8D%AC",
# "description": "바이오<b>파이썬</b> (Biopython) 프로젝트는 분자생물학 계산에 자유롭게 사용하기 위한 <b>파이썬</b> 라이브러리 구축 프로젝트이다. 같이 보기 바이오자바 바이오펄 외부 링크 biopython.org",
# "thumbnail": ""
#
# },
# {
# "title": "<b>파이썬</b>의 역사",
# "link": "https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9D%98_%EC%97%AD%EC%82%AC",
# "description": "프로그래밍 언어 <b>파이썬</b>은 1980년대 말에 구상되었으며 그 구현체는 1989년 12월 예외 처리가 가능하고 아메바 운영 체제와 통신이 가능한 ABC의 후속 프로그래밍 언어로서 CWI(Centrum Wiskunde... ",
# "thumbnail": ""
#
# },
# {
# "title": "아나콘다 (<b>파이썬</b> 배포판)",
# "link": "https://ko.wikipedia.org/wiki/%EC%95%84%EB%82%98%EC%BD%98%EB%8B%A4_(%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%B0%B0%ED%8F%AC%ED%8C%90)",
# "description": "아나콘다 (Anaconda)는 패키지 관리와 디플로이를 단순케 할 목적으로 과학 계산(데이터 과학, 기계 학습 애플리케이션, 대규모 데이터 처리, 예측 분석 등)을 위해 <b>파이썬</b>과 R 프로그래밍 언어의 자유... ",
# "thumbnail": ""
#
# },
# {
# "title": "<b>파이썬</b> 소프트웨어 재단",
# "link": "https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%86%8C%ED%94%84%ED%8A%B8%EC%9B%A8%EC%96%B4_%EC%9E%AC%EB%8B%A8",
# "description": "<b>파이썬</b> 소프트웨어 재단 (Python Software Foundation, PSF)은 <b>파이썬</b> 프로그래밍 언어에 헌신하는 비영리 단체로서, 2001년 3월 6일 런칭했다. 이 단체의 임무는 <b>파이썬</b> 공동체의 개발을 발전시키고... ",
# "thumbnail": ""
#
# },
# {
# "title": "자이썬",
# "link": "https://ko.wikipedia.org/wiki/%EC%9E%90%EC%9D%B4%EC%8D%AC",
# "description": "자이썬 ( Jython )은 <b>파이썬</b>의 자바 구현으로, Jim Hugunin에 의해 처음으로 만들어졌다. 처음에는 <b>파이썬</b> 표준 구현의 이름(CPython)을 따라 JPython 라는 이름을 썼다. 자이썬은 자바 언어로만 작성되었기... ",
# "thumbnail": ""
#
# }
# ]
# }

# %% [markdown]
# # 3. 상품 검색
# - 몰스킨

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "jOc7UxR_Sp1MMk2mwOq1"
client_secret = "s9PY8Vl3Wz"
encText = urllib.parse.quote('몰스킨')
url = "https://openapi.naver.com/v1/search/shop?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 12 Oct 2021 14:49:17 +0900",
# "total": 28970,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "한정판 <b>몰스킨</b> 2022 피너츠 위클리 다이어리 포켓",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28763297998",
# "image": "https://shopping-phinf.pstatic.net/main_2876329/28763297998.20210908210546.jpg",
# "lprice": "29810",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28763297998",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "<b>몰스킨</b> 2022 해리포터 데일리 다이어리 포캣",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28719894754",
# "image": "https://shopping-phinf.pstatic.net/main_2871989/28719894754.20210906035419.jpg",
# "lprice": "30060",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28719894754",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "<b>몰스킨</b> 2022 다이어리 데일리 위클리 포켓 고급 명품 감성 휴대용 여자 각인 해리포터",
# "link": "https://search.shopping.naver.com/gate.nhn?id=83374268420",
# "image": "https://shopping-phinf.pstatic.net/main_8337426/83374268420.jpg",
# "lprice": "26800",
# "hprice": "",
# "mallName": "에코펜",
# "productId": "83374268420",
# "productType": "2",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "<b>몰스킨</b> 클래식 노트 소프트커버 도트 포켓 머틀그린",
# "link": "https://search.shopping.naver.com/gate.nhn?id=24014924801",
# "image": "https://shopping-phinf.pstatic.net/main_2401492/24014924801.20200903021703.jpg",
# "lprice": "18810",
# "hprice": "",
# "mallName": "네이버",
# "productId": "24014924801",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "노트/수첩",
# "category4": "노트"
#
# },
# {
# "title": "<b>몰스킨</b> 클래식노트 플레인 하드 L",
# "link": "https://search.shopping.naver.com/gate.nhn?id=24031381534",
# "image": "https://shopping-phinf.pstatic.net/main_2403138/24031381534.20200904012957.jpg",
# "lprice": "19930",
# "hprice": "",
# "mallName": "네이버",
# "productId": "24031381534",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "노트/수첩",
# "category4": "노트"
#
# },
# {
# "title": "<b>몰스킨</b> 2022 데일리 다이어리 하드커버 포켓 4색상",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28719036749",
# "image": "https://shopping-phinf.pstatic.net/main_2871903/28719036749.20210906011032.jpg",
# "lprice": "26500",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28719036749",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "<b>몰스킨</b> 클래식노트 SOFT 하이드레인저",
# "link": "https://search.shopping.naver.com/gate.nhn?id=27370038858",
# "image": "https://shopping-phinf.pstatic.net/main_2737003/27370038858.20210530181457.jpg",
# "lprice": "18100",
# "hprice": "",
# "mallName": "네이버",
# "productId": "27370038858",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "노트/수첩",
# "category4": "노트"
#
# },
# {
# "title": "<b>몰스킨</b> 2021 위클리 소프트 P-",
# "link": "https://search.shopping.naver.com/gate.nhn?id=25430082807",
# "image": "https://shopping-phinf.pstatic.net/main_2543008/25430082807.20201230215155.jpg",
# "lprice": "19780",
# "hprice": "",
# "mallName": "네이버",
# "productId": "25430082807",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "한정판 <b>몰스킨</b> 2022 어린왕자 데일리 다이어리 포켓",
# "link": "https://search.shopping.naver.com/gate.nhn?id=28745540468",
# "image": "https://shopping-phinf.pstatic.net/main_2874554/28745540468.20210907204153.jpg",
# "lprice": "31960",
# "hprice": "",
# "mallName": "네이버",
# "productId": "28745540468",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# },
# {
# "title": "<b>몰스킨</b> <b>몰스킨</b> 2022 위클리 18개월 다이어리 소프트커버 라지 색상선택",
# "link": "https://search.shopping.naver.com/gate.nhn?id=27137560168",
# "image": "https://shopping-phinf.pstatic.net/main_2713756/27137560168.20210513175845.jpg",
# "lprice": "34360",
# "hprice": "",
# "mallName": "네이버",
# "productId": "27137560168",
# "productType": "1",
# "brand": "몰스킨",
# "maker": "몰스킨",
# "category1": "생활/건강",
# "category2": "문구/사무용품",
# "category3": "다이어리/플래너",
# "category4": "다이어리"
#
# }
# ]
# }

# %%
from PIL import Image
Image.open('../data/molskin.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1020x598 at 0x231CAC2D820>

# %% [markdown]
# ## (1) gen_search_url()

# %% [markdown]
# ```
# encText = urllib.parse.quote('몰스킨')
# url = "https://openapi.naver.com/v1/search/shop?query=" + encText # json 결과
# ```

# %%
def gen_search_url(api_node, search_text, start_num, disp_num):
    base = 'https://openapi.naver.com/v1/search'
    node = '/' + api_node + '.json'
    param_query = '?query=' + urllib.parse.quote(search_text)
    param_start = '&start=' + str(start_num)
    param_disp = '&display=' + str(disp_num)
    
    return base + node + param_query + param_start + param_disp

# %%
gen_search_url('shop', 'test', 10, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_167136/3342752695.py in <module>
# ----> 1 gen_search_url('shop', 'test', 10, 3)
#
# ~\AppData\Local\Temp/ipykernel_167136/740028441.py in gen_search_url(api_node, search_text, start_num, disp_num)
#       2     base = 'https://openapi.naver.com/v1/search/'
#       3     node = '/' + api_node + '.json'
# ----> 4     param_query = '?d_title=' + urllib.parse.quote(search_text)
#       5     categoryId = '&categoryId=280'
#       6     param_start = '&start=' + str(start_num)
#
# NameError: name 'urllib' is not defined

# %% [markdown]
# ## (2) get_result_onepage()

# %%
import json
import datetime

def get_result_onpage(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    print('[%s] Url Request Success' % datetime.datetime.now())
    return json.loads(response.read().decode('utf-8'))

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2021, 10, 12, 15, 28, 22, 364709)

# %%
url = gen_search_url('shop', '몰스킨', 1, 5)
one_result = get_result_onpage(url)
# Out:
# [2021-10-12 15:28:23.118067] Url Request Success

# %%
one_result
# Out:
# {'lastBuildDate': 'Tue, 12 Oct 2021 15:28:23 +0900',
#  'total': 28963,
#  'start': 1,
#  'display': 5,
#  'items': [{'title': '한정판 <b>몰스킨</b> 2022 피너츠 위클리 다이어리 포켓',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=28763297998',
#    'image': 'https://shopping-phinf.pstatic.net/main_2876329/28763297998.20210908210546.jpg',
#    'lprice': '29810',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '28763297998',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 2022 해리포터 데일리 다이어리 포캣',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=28719894754',
#    'image': 'https://shopping-phinf.pstatic.net/main_2871989/28719894754.20210906035419.jpg',
#    'lprice': '30060',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '28719894754',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 2022 다이어리 데일리 위클리 포켓 고급 명품 감성 휴대용 여자 각인 해리포터',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=83374268420',
#    'image': 'https://shopping-phinf.pstatic.net/main_8337426/83374268420.jpg',
#    'lprice': '26800',
#    'hprice': '',
#    'mallName': '에코펜',
#    'productId': '83374268420',
#    'productType': '2',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '다이어리/플래너',
#    'category4': '다이어리'},
#   {'title': '<b>몰스킨</b> 클래식 노트 소프트커버 도트 포켓 머틀그린',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=24014924801',
#    'image': 'https://shopping-phinf.pstatic.net/main_2401492/24014924801.20200903021703.jpg',
#    'lprice': '18810',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '24014924801',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '노트/수첩',
#    'category4': '노트'},
#   {'title': '<b>몰스킨</b> 클래식노트 플레인 하드 L',
#    'link': 'https://search.shopping.naver.com/gate.nhn?id=24031381534',
#    'image': 'https://shopping-phinf.pstatic.net/main_2403138/24031381534.20200904012957.jpg',
#    'lprice': '19930',
#    'hprice': '',
#    'mallName': '네이버',
#    'productId': '24031381534',
#    'productType': '1',
#    'brand': '몰스킨',
#    'maker': '몰스킨',
#    'category1': '생활/건강',
#    'category2': '문구/사무용품',
#    'category3': '노트/수첩',
#    'category4': '노트'}]}

# %%
one_result['items'][0]['title']
# Out:
# '한정판 <b>몰스킨</b> 2022 피너츠 위클리 다이어리 포켓'

# %%
one_result['items'][0]['link']
# Out:
# 'https://search.shopping.naver.com/gate.nhn?id=28763297998'

# %%
one_result['items'][0]['lprice']
# Out:
# '29810'

# %%
one_result['items'][0]['mallName']
# Out:
# '네이버'

# %% [markdown]
# ## (3) get_fields()

# %%
one_result['items'][0]
# Out:
# {'title': '한정판 <b>몰스킨</b> 2022 피너츠 위클리 다이어리 포켓',
#  'link': 'https://search.shopping.naver.com/gate.nhn?id=28763297998',
#  'image': 'https://shopping-phinf.pstatic.net/main_2876329/28763297998.20210908210546.jpg',
#  'lprice': '29810',
#  'hprice': '',
#  'mallName': '네이버',
#  'productId': '28763297998',
#  'productType': '1',
#  'brand': '몰스킨',
#  'maker': '몰스킨',
#  'category1': '생활/건강',
#  'category2': '문구/사무용품',
#  'category3': '다이어리/플래너',
#  'category4': '다이어리'}

# %%
import pandas as pd

def get_fields(json_data):
    title = [each['title'] for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]
    
    result_pd = pd.DataFrame({
        'title': title,
        'link': link,
        'lprice': lprice,
        'mall': mall_name
    }, columns = ['title', 'lprice', 'link', 'mall'])
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                                title lprice  \
# 0                한정판 <b>몰스킨</b> 2022 피너츠 위클리 다이어리 포켓  29810
# 1                   <b>몰스킨</b> 2022 해리포터 데일리 다이어리 포캣  30060
# 2  <b>몰스킨</b> 2022 다이어리 데일리 위클리 포켓 고급 명품 감성 휴대용 여...  26800
# 3                 <b>몰스킨</b> 클래식 노트 소프트커버 도트 포켓 머틀그린  18810
# 4                          <b>몰스킨</b> 클래식노트 플레인 하드 L  19930
#
#                                                 link mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  에코펜
# 3  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %% [markdown]
# ## (4) delete_tag()

# %%
def delete_tag(input_str):
    input_str = input_str.replace('<b>', '')
    input_str = input_str.replace('</b>', '')
    return input_str

# %%
import pandas as pd

def get_fields(json_data):
    title = [delete_tag(each['title']) for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]
    
    result_pd = pd.DataFrame({
        'title': title,
        'link': link,
        'lprice': lprice,
        'mall': mall_name
    }, columns = ['title', 'lprice', 'link', 'mall'])
    return result_pd

# %%
get_fields(one_result)
# Out:
#                                               title lprice  \
# 0                      한정판 몰스킨 2022 피너츠 위클리 다이어리 포켓  29810
# 1                         몰스킨 2022 해리포터 데일리 다이어리 포캣  30060
# 2  몰스킨 2022 다이어리 데일리 위클리 포켓 고급 명품 감성 휴대용 여자 각인 해리포터  26800
# 3                       몰스킨 클래식 노트 소프트커버 도트 포켓 머틀그린  18810
# 4                                몰스킨 클래식노트 플레인 하드 L  19930
#
#                                                 link mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  에코펜
# 3  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %%
url = gen_search_url('shop', '몰스킨', 1, 5)
json_result = get_result_onpage(url)
pd_result = get_fields(json_result)
# Out:
# [2021-10-12 15:28:52.705400] Url Request Success

# %%
pd_result
# Out:
#                                               title lprice  \
# 0                      한정판 몰스킨 2022 피너츠 위클리 다이어리 포켓  29810
# 1                         몰스킨 2022 해리포터 데일리 다이어리 포캣  30060
# 2  몰스킨 2022 다이어리 데일리 위클리 포켓 고급 명품 감성 휴대용 여자 각인 해리포터  26800
# 3                       몰스킨 클래식 노트 소프트커버 도트 포켓 머틀그린  18810
# 4                                몰스킨 클래식노트 플레인 하드 L  19930
#
#                                                 link mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  에코펜
# 3  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %% [markdown]
# ## (5) actMain()

# %%
for n in range(1, 1000 ,100):
    print(n)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901

# %%
result_mol = []

for n in range(1, 1000, 100):
    url = gen_search_url('shop', '몰스킨', n, 100)
    json_result = get_result_onpage(url)
    pd_result = get_fields(json_result)
    
    result_mol.append(pd_result)
    
result_mol = pd.concat(result_mol)
# Out:
# [2021-10-12 15:28:56.121618] Url Request Success
# [2021-10-12 15:28:56.486266] Url Request Success
# [2021-10-12 15:28:56.815831] Url Request Success
# [2021-10-12 15:28:57.212592] Url Request Success
# [2021-10-12 15:28:57.613074] Url Request Success
# [2021-10-12 15:28:58.020016] Url Request Success
# [2021-10-12 15:28:58.535158] Url Request Success
# [2021-10-12 15:28:58.952209] Url Request Success
# [2021-10-12 15:28:59.695124] Url Request Success
# [2021-10-12 15:29:00.087515] Url Request Success

# %%
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
result_mol.reset_index(drop=True, inplace=True)
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   object
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
result_mol.head()
# Out:
#                                               title lprice  \
# 0                      한정판 몰스킨 2022 피너츠 위클리 다이어리 포켓  29810
# 1                         몰스킨 2022 해리포터 데일리 다이어리 포캣  30060
# 2  몰스킨 2022 다이어리 데일리 위클리 포켓 고급 명품 감성 휴대용 여자 각인 해리포터  26800
# 3                       몰스킨 클래식 노트 소프트커버 도트 포켓 머틀그린  18810
# 4                                몰스킨 클래식노트 플레인 하드 L  19930
#
#                                                 link mall
# 0  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 1  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 2  https://search.shopping.naver.com/gate.nhn?id=...  에코펜
# 3  https://search.shopping.naver.com/gate.nhn?id=...  네이버
# 4  https://search.shopping.naver.com/gate.nhn?id=...  네이버

# %%
result_mol.tail()
# Out:
#                                  title lprice  \
# 995                         몰스킨 리딩 스탠드  25300
# 996             몰스킨 [19 원더 우먼] 룰드/레드 L  39900
# 997            몰스킨 [18바비]플레인/스윔수트 핑크 L  39600
# 998  몰스킨 한정판 스타워즈 2020 위클리/데일리 하드커버 노트  29500
# 999            몰스킨 T 아이폰11프로-북타입 리딩/블랙  45900
#
#                                                   link    mall
# 995  https://search.shopping.naver.com/gate.nhn?id=...   펜샵코리아
# 996  https://search.shopping.naver.com/gate.nhn?id=...  교보핫트랙스
# 997  https://search.shopping.naver.com/gate.nhn?id=...  교보핫트랙스
# 998  https://search.shopping.naver.com/gate.nhn?id=...     홍길동
# 999  https://search.shopping.naver.com/gate.nhn?id=...  교보핫트랙스

# %%
result_mol['lprice'] = result_mol['lprice'].astype('float')
result_mol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   1000 non-null   object
#  1   lprice  1000 non-null   float64
#  2   link    1000 non-null   object
#  3   mall    1000 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# ## (5) to_excel()

# %%
# !pip install xlsxwriter

# %%
writer = pd.ExcelWriter('../data/06_molskin_diary_in_naver_shop(2).xlsx', engine='xlsxwriter')
result_mol.to_excel(writer, sheet_name='Sheet1')

workbook = writer.book
worksheet = writer.sheets['Sheet1']
worksheet.set_column('A:A', 4)
worksheet.set_column('B:B', 60)
worksheet.set_column('C:C', 10)
worksheet.set_column('D:D', 10)
worksheet.set_column('E:E', 50)
worksheet.set_column('F:F', 10)

worksheet.conditional_format('C2:C1001', {'type': '3_color_scale'})
writer.save()

# %%
# !dir "../data/06_molskin_diary_in_naver_shop(2).xlsx"
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 9AEB-3250
#
#  C:\Users\seonwook\Documents\ds_study\data 디렉터리
#
# 2021-10-12  오후 03:37            73,304 06_molskin_diary_in_naver_shop(2).xlsx
#                1개 파일              73,304 바이트
#                0개 디렉터리  822,018,744,320 바이트 남음

# %% [markdown]
# ## (6) 시각화

# %%
import set_matplotlib_hangul
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 6))
sns.countplot(
    result_mol['mall'],
    data=result_mol,
    palette='RdYlGn',
    order=result_mol['mall'].value_counts().index
)
plt.xticks(rotation=90) # x축 이름 90도 회전
plt.show()
# Out:
# C:\Users\seonwook\miniconda3\envs\ds_study\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
